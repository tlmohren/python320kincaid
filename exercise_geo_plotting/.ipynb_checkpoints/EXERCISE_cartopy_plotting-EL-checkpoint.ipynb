# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("./data/final_loc_data.csv")
df.time = pd.to_datetime(df.time)
df.head()
# Out:
#         time  site  precip  rh  solrad  temp    lat    lon  \
# 0 1961-01-01  3103     NaN NaN     NaN   NaN  35.08  111.4
# 1 1961-02-01  3103     NaN NaN     NaN   NaN  35.08  111.4
# 2 1961-03-01  3103     NaN NaN     NaN   NaN  35.08  111.4
# 3 1961-04-01  3103     NaN NaN     NaN   NaN  35.08  111.4
# 4 1961-05-01  3103     NaN NaN     NaN   NaN  35.08  111.4
#
#                      city state
# 0  FLAGSTAFF                 AZ
# 1  FLAGSTAFF                 AZ
# 2  FLAGSTAFF                 AZ
# 3  FLAGSTAFF                 AZ
# 4  FLAGSTAFF                 AZ

# %%
print(len(df.city.unique()))
# Out:
# 229

# %%
df.describe(include="all")
# Out:
#                        time          site        precip            rh  \
# count                 85320  85320.000000  51949.000000  58346.000000
# unique                  360           NaN           NaN           NaN
# top     1987-03-01 00:00:00           NaN           NaN           NaN
# freq                    237           NaN           NaN           NaN
# first   1961-01-01 00:00:00           NaN           NaN           NaN
# last    1990-12-01 00:00:00           NaN           NaN           NaN
# mean                    NaN  28913.645570      1.874993      0.588095
# std                     NaN  27801.387843     17.083766      0.221197
# min                     NaN   3103.000000      0.000000      0.013988
# 25%                     NaN  13963.000000      0.000000      0.430797
# 50%                     NaN  21504.000000      0.000000      0.604065
# 75%                     NaN  24229.000000      0.000000      0.759301
# max                     NaN  94910.000000   1560.000000      1.000000
#
#               solrad          temp           lat           lon  \
# count   85164.000000  58466.000000  85320.000000  85320.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# first            NaN           NaN           NaN           NaN
# last             NaN           NaN           NaN           NaN
# mean        0.022169     14.417061     39.992700     99.651392
# std         0.744232     12.210379      8.569895     22.557295
# min         0.000000    -46.100000     13.330000     66.000000
# 25%         0.000000      6.100000     35.030000     82.530000
# 50%         0.000000     16.100000     40.300000     94.010000
# 75%         0.000000     23.900000     43.390000    112.010000
# max        44.000000     46.100000     71.180000    170.130000
#
#                           city  state
# count                    85320  85320
# unique                     229     52
# top     SPRINGFIELD                AK
# freq                       720   6120
# first                      NaN    NaN
# last                       NaN    NaN
# mean                       NaN    NaN
# std                        NaN    NaN
# min                        NaN    NaN
# 25%                        NaN    NaN
# 50%                        NaN    NaN
# 75%                        NaN    NaN
# max                        NaN    NaN

# %%
df = df.sort_values(by=["time", 'lat'])
groups = df.groupby("time")

fig = plt.figure(figsize=(10,30))
ax = fig.add_subplot(111)
for name, group in groups: 
    ax.scatter([name]*len(group), group.city, c=group.temp, cmap='magma')
plt.show()
