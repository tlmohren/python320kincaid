# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
IrisData=np.loadtxt('iris-data.txt', dtype={'names': ('sepal length in cm', 'sepal width in cm', 'petal length in cm',
                                                     'petal width in cm ','species name'), 
                                            'formats': ('f2', 'f2', 'f2', 'f2', 'S')}, 
                    delimiter=',')

# %%
IrisData.shape
# Out:
# (150,)

# %%
type(IrisData)
# Out:
# numpy.ndarray

# %%
IrisData[0]
# Out:
# ( 5.1015625,  3.5,  1.40039062,  0.19995117, b'')

# %%
# load as panda data structure
irisData_pandaStyle = pd.read_csv('iris-data.txt', header=None)

# %%
# test if we have the right data type
irisData_pandaStyle.loc[0,:]
# Out:
# 0            5.1
# 1            3.5
# 2            1.4
# 3            0.2
# 4    Iris-setosa
# Name: 0, dtype: object

# %%
# replace species names as integers to use for color code in plotting
irisData_pandaStyle.replace(to_replace=['Iris-setosa', 'Iris-versicolor','Iris-virginica', ], value=[1,2,3])
# Out:
#        0    1    2    3  4
# 0    5.1  3.5  1.4  0.2  1
# 1    4.9  3.0  1.4  0.2  1
# 2    4.7  3.2  1.3  0.2  1
# 3    4.6  3.1  1.5  0.2  1
# 4    5.0  3.6  1.4  0.2  1
# 5    5.4  3.9  1.7  0.4  1
# 6    4.6  3.4  1.4  0.3  1
# 7    5.0  3.4  1.5  0.2  1
# 8    4.4  2.9  1.4  0.2  1
# 9    4.9  3.1  1.5  0.1  1
# 10   5.4  3.7  1.5  0.2  1
# 11   4.8  3.4  1.6  0.2  1
# 12   4.8  3.0  1.4  0.1  1
# 13   4.3  3.0  1.1  0.1  1
# 14   5.8  4.0  1.2  0.2  1
# 15   5.7  4.4  1.5  0.4  1
# 16   5.4  3.9  1.3  0.4  1
# 17   5.1  3.5  1.4  0.3  1
# 18   5.7  3.8  1.7  0.3  1
# 19   5.1  3.8  1.5  0.3  1
# 20   5.4  3.4  1.7  0.2  1
# 21   5.1  3.7  1.5  0.4  1
# 22   4.6  3.6  1.0  0.2  1
# 23   5.1  3.3  1.7  0.5  1
# 24   4.8  3.4  1.9  0.2  1
# 25   5.0  3.0  1.6  0.2  1
# 26   5.0  3.4  1.6  0.4  1
# 27   5.2  3.5  1.5  0.2  1
# 28   5.2  3.4  1.4  0.2  1
# 29   4.7  3.2  1.6  0.2  1
# ..   ...  ...  ...  ... ..
# 120  6.9  3.2  5.7  2.3  3
# 121  5.6  2.8  4.9  2.0  3
# ...

# %%
# plot to see patterns
plt.scatter(test.loc[:,1],test.loc[:,2])
plt.xlabel('sepal length in cm')
plt.ylabel('sepal width in cm')
plt.title('1 and 2')
plt.show()


c='Animation', colormap='jet'
